# %% [markdown]
# <font face="B Mitra" size=4>
# <div dir=rtl align=center>
# <br>
# <img src="https://aut.ac.ir/templates/tmpl_modern01/images/logo_fa.png" alt="Amirkabir University Logo" width="100">
# <br>
# <font size=6>
# <b>پروژه اول داده کاوی</b>
# <br>
# <b><font size=5> استاد درس: دکتر فاطمه شاکری</b>
# <hr>
# </div>
# </font>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5><font color='red'>
# توجه داشته باشید علاوه بر پیاده سازی خواسته شده، توضیحات لازم در محل تعریف شده را بیان کنید.
# </p>
# </font>
# </div>
# </font>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <font size=6>
# <b> معرفی مجموعه داده </b>
# <br>
# <p align="justify">
# <font size=5>
# در این روزها، روابط کاری بیش از پیش به اعتماد متکی می‌شوند، و قراردادهای سخت گیرانه (که زمان کاری به دقت نظارت می‌شود) با قراردادهای انعطاف‌پذیرتر جایگزین می‌شوند که در آن کارمند به طور فردی مسئولیت حسابرسی زمان کاری را بر عهده دارد. این آزادی ممکن است منجر به غیبت بدون نظارت شود ، حتی اگر ساعات غیبت با دلایل معتبر قابل محاسبه باشد. این می‌تواند به طور قابل توجهی به روابط کاری سالم آسیب بزند. به علاوه، غیبت بدون نظارت می‌تواند تأثیر منفی بر بهره‌وری کاری داشته باشد
#
# هدف ما کشف الگوهای پنهان در داده‌هاست که ممکن است برای تمایز بین غیبت‌های واقعی از غیبت‌های تقلبی مفید باشند.
# همچنین با بررسی دلایل غیبت و تجدیدنظر در روند استخدامی در آینده ، میزان غیبت کاری را به حداقل رساند یا طرح هایی برای کاهش این ساعات درنظر گرفت.
# </p>
# </font>
# </div>
# </font>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <font size=5>
# <b> بارگذاری کتابخانه های موردنیاز </b>
# <br>
# </div>
# </font>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <font size=5>
# <b> بارگذاری مجموعه داده </b>
# <br>
# </div>
# </font>

# %%
file_path = 'Dataset.xls'
df = pd.read_excel(file_path)
df.head()
# Out:
#    Employee_ID  Absence_Reason        Date  Transportation_Expense  \
# 0           11              26  07/07/2015                     289
# 1           36               0  14/07/2015                     118
# 2            3              23  15/07/2015                     179
# 3            7               7  16/07/2015                     279
# 4           11              23  23/07/2015                     289
#
#    Distance_to_Work  Employment_Service_Time  Employee_Age  \
# 0                36                       13            33
# 1                13                       18            50
# 2                51                       18            38
# 3                 5                       14            39
# 4                36                       13            33
#
#    Daily_Workload_Average  Target_Achievement_Rate  Disciplinary_Incident  \
# 0                  239554                       97                      0
# ...

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <font size=6>
# <b> پیش پردازش </b>
# <p align="justify">
# <font size=5>
# ابعاد داده را چاپ کنید.
# </p>
# </font>
# </div>
# </font>

# %%
print(df.shape)
# Out:
# (700, 18)

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5>
#  مقادیر گمشده را در مجموعه داده بررسی کنید.
# </p>
# </font>
# </div>
# </font>

# %%
missing_values = df.isna()
print(missing_values)

missing_counts = df.isna().sum()


print(missing_counts)
# Out:
#      Employee_ID  Absence_Reason   Date  Transportation_Expense  \
# 0          False           False  False                   False
# 1          False           False  False                   False
# 2          False           False  False                   False
# 3          False           False  False                   False
# 4          False           False  False                   False
# ..           ...             ...    ...                     ...
# 695        False           False  False                   False
# 696        False           False  False                   False
# 697        False           False  False                   False
# 698        False           False  False                   False
# 699        False           False  False                   False
#
#      Distance_to_Work  Employment_Service_Time  Employee_Age  \
# 0               False                    False         False
# 1               False                    False         False
# ...

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5>
# مقادیر آماری را به شکل زیر نشان دهید.
# </p>
# </font>
# </div>
# </font>

# %%
initial_statistics = df.describe()
print(initial_statistics)
# Out:
#        Employee_ID  Absence_Reason  Transportation_Expense  Distance_to_Work  \
# count   700.000000      700.000000              700.000000        700.000000
# mean     17.951429       19.411429              222.347143         29.892857
# std      11.028144        8.356292               66.312960         14.804446
# min       1.000000        0.000000              118.000000          5.000000
# 25%       9.000000       13.000000              179.000000         16.000000
# 50%      18.000000       23.000000              225.000000         26.000000
# 75%      28.000000       27.000000              260.000000         50.000000
# max      36.000000       28.000000              388.000000         52.000000
#
#        Employment_Service_Time  Employee_Age  Daily_Workload_Average  \
# count               700.000000    700.000000              700.000000
# mean                 12.658571     36.417143           271801.774286
# ...

# %% [markdown]
# <div align=center>
# <br>
# <img src="https://drive.google.com/uc?id=1qM-jhi6ZXCHRBwgRShaYEV4ag4Pfd9gL" alt="Linear Algebra Cover Art" width="800">
# <br>
# </div>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5>
# رکوردهای تکراری را در مجموعه داده بررسی کنید و درصورت نیاز حذف کنید.
# </p>
# </font>
# </div>
# </font>

# %%
duplicate_rows = df[df.duplicated()]
print(duplicate_rows)

print("/////////////////////////////////////////////////////////////////////////////////////////////////////////////")
df_without_duplicates = df.drop_duplicates()
print(df_without_duplicates)
# Out:
#      Employee_ID  Absence_Reason        Date  Transportation_Expense  \
# 127           34              27  11/01/2016                     118
# 128           34              27  12/01/2016                     118
# 131           34              27  13/01/2016                     118
# 305            5              23  19/10/2016                     235
# 388            3              27  22/02/2017                     179
# 389            3              27  24/02/2017                     179
# 477           24              28  25/07/2017                     246
# 496           24              28  05/09/2017                     246
#
#      Distance_to_Work  Employment_Service_Time  Employee_Age  \
# 127                10                       10            37
# 128                10                       10            37
# 131                10                       10            37
# 305                20                       13            43
# ...

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5>
# با توجه به اینکه ویژگی Employee_ID ارزش اطلاعاتی ندارد، این ستون را حذف کنید.
# </p>
# </font>
# </div>
# </font>

# %%
df_without_column = df.drop(columns=['Employee_ID'])
print(df_without_column)
# Out:
#      Absence_Reason        Date  Transportation_Expense  Distance_to_Work  \
# 0                26  07/07/2015                     289                36
# 1                 0  14/07/2015                     118                13
# 2                23  15/07/2015                     179                51
# 3                 7  16/07/2015                     279                 5
# 4                23  23/07/2015                     289                36
# ..              ...         ...                     ...               ...
# 695              10  23/05/2018                     179                22
# 696               6  23/05/2018                     225                26
# 697              10  24/05/2018                     330                16
# 698              23  24/05/2018                     235                16
# 699              28  31/05/2018                     291                31
#
#      Employment_Service_Time  Employee_Age  Daily_Workload_Average  \
# ...

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5>
# ویژگی Date به شکل Series ذخیره شده است که دیتاتایپ مناسبی برای تحلیل سایر ویژگی ها بر اساس تاریخ نیست. ابتدا آن را به شکل Timestamp در آوردیم.
# <br>
# هر یک از مقادیر روزهفته ، ماه، سال را از آن استخراج کنید و در یک ستون جداگانه قرار دهید تا بتوانیم تحلیل هایی در ارتباط با تاریخ در ادامه انجام دهیم.
# <br>
# درنهایت ستون Date را حذف کنید.
# </p>
# </font>
# </div>
# </font>

# %%
type(df["Date"])
# Out:
# pandas.core.series.Series

# %%
# convert it to a date-time
df["Date"] = pd.to_datetime(df["Date"], format = '%d/%m/%Y')
# display the first date
df["Date"][0]
# Out:
# Timestamp('2015-07-07 00:00:00')

# %%
# extracting the Year out of the date
df['Year'] = df['Date'].dt.year
print(df['Year'])
# Out:
# 0      2015
# 1      2015
# 2      2015
# 3      2015
# 4      2015
#        ...
# 695    2018
# 696    2018
# 697    2018
# 698    2018
# 699    2018
# Name: Year, Length: 700, dtype: int32

# %%
# extracting the Month out of the date
df['month'] = df['Date'].dt.month
print(df['month'])
# Out:
# 0      7
# 1      7
# 2      7
# 3      7
# 4      7
#       ..
# 695    5
# 696    5
# 697    5
# 698    5
# 699    5
# Name: month, Length: 700, dtype: int32

# %%
# extracting the Weekday out of the date
df['day'] = df['Date'].dt.day
print(df['day'])

df = df.drop(columns=['Date'])
print(df)
# Out:
# 0       7
# 1      14
# 2      15
# 3      16
# 4      23
#        ..
# 695    23
# 696    23
# 697    24
# 698    24
# 699    31
# Name: day, Length: 700, dtype: int32
#      Employee_ID  Absence_Reason  Transportation_Expense  Distance_to_Work  \
# 0             11              26                     289                36
# 1             36               0                     118                13
# 2              3              23                     179                51
# 3              7               7                     279                 5
# 4             11              23                     289                36
# ..           ...             ...                     ...               ...
# 695           17              10                     179                22
# 696           28               6                     225                26
# 697           18              10                     330                16
# ...

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5>
# دقت کنید که ویژگی های "Education_Level" , "Disciplinary_Incident" , "Social_Drinker_Status"و "Social_Smoker_Status" ویژگی های categorical هستند که به شکل عددی یا بولی ذخیره شده اند. بنابراین میتوانیم برای نمایش بهتر ویژگی ها به فرم categorical برگردانیم.
# </p>
# </font>
# </div>
# </font>

# %%
education_encoding = {1: "high_school", 2: "graduate", 3: "postgraduate", 4: "master_phd"}
yes_no_encoding = {0: "No", 1: "Yes"}
# FILL HERE
# Map numerical values to categorical values
df['Education_Level1'] = df['Education_Level'].map(education_encoding)
df['Disciplinary_Incident1'] = df['Disciplinary_Incident'].map(yes_no_encoding)
df['Social_Drinker_Status1'] = df['Social_Drinker_Status'].map(yes_no_encoding)
df['Social_Smoker_Status1'] = df['Social_Smoker_Status'].map(yes_no_encoding)

print(df['Education_Level1'])
# Out:
# 0       high_school
# 1       high_school
# 2       high_school
# 3       high_school
# 4       high_school
#            ...
# 695        graduate
# 696     high_school
# 697        graduate
# 698    postgraduate
# 699     high_school
# Name: Education_Level1, Length: 700, dtype: object

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <font size=6>
# <b> EDA </b>
# <p align="justify">
# <font size=5>
# ما تلاش خواهیم کرد تا به سوالاتی مانند،  کدام عامل بیشترین غیبت را ایجاد می‌کند؟ آیا مصرف الکل یا دخانیات تأثیری بر دلایل دارد؟ آیا فاصله تا محل کار تأثیری بر علت غیبت دارد؟ و غیره، پاسخ دهیم. شروع با این نوع سوالات هنگام تحلیل داده اغلب مهم است ، زیرا این روش یک راه خوب برای به دست آوردن اطمینان و درک از داده‌هاست.
# </p>
# </font>
# <font size=5>
# <b>1.تشخیص دلایل غیبت </b>
# <br>
# 1.1. در ابتدا با استفاده از barplot و ویژگی Absence_Reason بررسی کنید سه دلیل پرتکرار غیبت در بین کارمندان چیست.
# </div>
# </font>

# %%
  #FILL HERE
  top_absence_reasons = df['Absence_Reason'].value_counts().head(3)
  print(top_absence_reasons)
  sns.set(style="whitegrid")
  plt.figure(figsize=(10, 6))
  ax = sns.barplot(x=top_absence_reasons.index, y=top_absence_reasons.values, palette="viridis")
# Out:
# Absence_Reason
# 23    147
# 28    110
# 27     66
# Name: count, dtype: int64
# C:\Users\msi\AppData\Local\Temp\ipykernel_21812\1980648017.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=top_absence_reasons.index, y=top_absence_reasons.values, palette="viridis")

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ:</font> </b> با این حرکت سه دلیل که بیشترین تعداد دلیل غیبت را دارند نشون داده می شود با نمودار میله با یک نگاه سریع می توان بیشترین و کمترین را مشاهده نمود
# </p>
# </font>
# </div>
# </font>
# <hr>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <font size=5>
# 2.1. توجه داشته باشید که فقط مقادیر 1 تا 21 کدهای موجود در جدول ICD را نشان میدهد.از آنجایی که تمام مقادیر موجود در ICD نشاندهنده یک نوع بیماری است،
# یک متغیر binary جدید تحت عنوان Disease تعریف کنید که بررسی کند دلیل غیبت  برای هر شخص در بازه ICD قرار دارد یا خیر.
# </div>
# </font>

# %%
  icd_values = list(range(1, 22))
  df['Disease'] = df['Absence_Reason'].isin(icd_values)
  print(df['Disease'])
  print(df)
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 695     True
# 696     True
# 697     True
# 698    False
# 699    False
# Name: Disease, Length: 700, dtype: bool
#      Employee_ID  Absence_Reason  Transportation_Expense  Distance_to_Work  \
# 0             11              26                     289                36
# 1             36               0                     118                13
# 2              3              23                     179                51
# 3              7               7                     279                 5
# 4             11              23                     289                36
# ..           ...             ...                     ...               ...
# 695           17              10                     179                22
# 696           28               6                     225                26
# 697           18              10                     330                16
# ...

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5>
# 3.1. سپس از barplot برای مقایسه تعداد افراد دو گروه بالا استفاده کنید.
# <br>
# تحلیل خود را از این نمودار بیان کنید.
# </p>
# </font>
# </div>
# </font>

# %%
#FILL HERE
top_Disease = df['Disease'].value_counts().head(2)
print(top_Disease)
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
ax = sns.barplot(x=top_Disease.index, y=top_Disease.values, palette="viridis")
# Out:
# Disease
# False    456
# True     244
# Name: count, dtype: int64
# C:\Users\msi\AppData\Local\Temp\ipykernel_21812\2022760286.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=top_Disease.index, y=top_Disease.values, palette="viridis")

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ: </font></b>  با این نمودار متوجه می شویم نزدیک به دو سوم به بیمار نبودند و غیبت کرده اند.
#
# </p>
# </font>
# </div>
# </font>
# <hr>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <font size=5>
# <b> 2. تحلیل مصرف کنندگان الکل و سیگار </b>
# <p align="justify">
# <font size=5>
# با تجزیه و تحلیل تأثیر مصرف الکل یا دخانیات بر غیبت کارکنان شروع کنیم. با توجه به اینکه سیگار کشیدن و مصرف مکرر الکل تأثیر منفی بر شرایط سلامتی دارند، انتظار داریم که برخی از بیماری‌ها در سیگاری‌ها و مصرف‌کنندگان الکل بیشتر از دیگران باشند.
# <br>
# 1.2. بررسی کنید چند درصد از غیبت ها،از گروه مصرف کننده الکل و چند درصد سیگاری هستند.
# </p>
# </font>
# </div>
# </font>

# %%
#FILL HERE
all_absences = df[df['Absence_Duration_Hours'] != 0].shape[0]
absences_from_alcohol_consumers = df[(df['Social_Drinker_Status'] == 1) & (df['Absence_Duration_Hours'] != 0)].shape[0]
absences_from_smokers = df[(df['Social_Smoker_Status'] == 1) & (df['Absence_Duration_Hours'] != 0)].shape[0]
percent_absences_from_alcohol_consumers = (absences_from_alcohol_consumers / all_absences) * 100
percent_absences_from_smokers = (absences_from_smokers / all_absences) * 100


print("percent_absences_from_alcohol_consumers", percent_absences_from_alcohol_consumers)
print("percent_absences_from_smokers", percent_absences_from_smokers)
# Out:
# percent_absences_from_alcohol_consumers 56.88350983358548
# percent_absences_from_smokers 6.505295007564296

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5>
# 2.2. با توجه به درصد قابل توجه مصرف کنندگان الکل، با استفاده از barplot توزیع دلایل غیبت را در میان مصرف کنندگان الکل نشان دهید.
# همچنین  با تحلیل بصری این نمودار بررسی کنید که بیشترین اختلاف بین مصرف کنندگان الکل و سایرین در غیبت کاری، مرتبط با چه دلیلی است.
# </p>
# </font>
# </div>
# </font>

# %%
#FILL HERE
alcohol_consumers_df = df[df['Social_Drinker_Status'] == 1]
absence_reason_counts = alcohol_consumers_df[alcohol_consumers_df['Absence_Reason'] != 0]['Absence_Reason'].value_counts()


sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

ax = sns.barplot(x=absence_reason_counts.index, y=absence_reason_counts.values, palette="viridis")
# Out:
# C:\Users\msi\AppData\Local\Temp\ipykernel_21812\1460988402.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=absence_reason_counts.index, y=absence_reason_counts.values, palette="viridis")

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ: </font></b>  به نمودار میله سریع متوجه میشیم بیشترین دلیل و کمترین دلیل چه بوده و یک مقایسه سریع متوجه میشیم دلیل های مختلف نسبت بهم چگونه هستن مثلا متوجه می شویم بیشترین دلیل غیبت برای مورد 28 بوده و بعد از ان مورد 23
# </p>
# </font>
# </div>
# </font>
# <hr>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5>
# 3.2. برای تکمیل تحلیل مصرف کنندگان الکل و سیگار، با استفاده از violin plot توزیع تعداد ساعات غیبت را بین دو کلاس(مصرف کنندگان الکل و سایرین) بررسی کنید.
# <br>
# این تحلیل را به صورت مشابه برای افراد سیگار و سایرین انجام دهید.
# <br>
# همچنین توضیح دهید که violin plot برای تحلیل بصری در چه مواقعی مناسب است.
# </p>
# </font>
# </div>
# </font>

# %%
#FILL HERE

plt.figure(figsize=(10, 6))
sns.violinplot(x='Social_Drinker_Status1', y='Absence_Duration_Hours', data=df)
plt.title('Distribution of Absence Hours between Alcohol Consumers and Others')
plt.xlabel('Alcohol Consumption')
plt.ylabel('Absence Duration (Hours)')
plt.show()


plt.figure(figsize=(10, 6))
sns.violinplot(x='Social_Smoker_Status1', y='Absence_Duration_Hours', data=df)
plt.title('Distribution of Absence Hours between Smokers and Others')
plt.xlabel('Smoking')
plt.ylabel('Absence Duration (Hours)')
plt.show()

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ: </font></b>  violin Plot مناسب  زمانی که می‌خواهید توزیع داده‌ها را به صورت احتمالی مشاهده کنید و همچنین برای مقایسه توزیع داده بین چند گروه مختلف. این نوع نمودار به شما اطلاعاتی درباره مرکز و پراکندگی داده‌ها، شکل توزیع و حتی وجود الگوهای مختلف در داده‌ها را ارائه می‌دهد که در تحلیل‌های بصری و تفسیر داده مفید است.
# </p>
# </font>
# </div>
# </font>
# <hr>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <font size=5>
# <b> 3. فاکتورهای هزینه حمل و نقل و فاصله تا محل کار </b>
# <p align="justify">
# <font size=5>
# دو شاخص ممکن برای غیبت ممکن است فاصله بین خانه و محل کار و هزینه‌های حمل و نقل (ستون هزینه حمل و نقل) باشد. کارمندانی که باید مسافت بیشتری را طی کنند یا هزینه‌های حمل و نقل به محل کار آن‌ها بالاتر است، ممکن است به غیبت بیشتری دچار شوند. در این بخش، رابطه بین این متغیرها و زمان غیبت به ساعت را بررسی خواهیم کرد.
# <br>
#  از آنجا که ما اعتقاد نداریم که عوامل مذکور ممکن است نشان‌دهنده مشکلات بیماری باشند به معنای دیگر به طور ذاتی عامل بیماری نباشد، ما رابطه ممکن با ستون دلیل غیبت را در نظر نخواهیم گرفت و به بررسی رابطه آن با زمان غیبت بسنده میکنیم.
# <br>
# 1.3. با استفاده از joint plot رابطه بین فاصله محل اقامت تا کار و ساعات غیبت را نمایش دهید.
# <br>
# تحلیل بصری مشابهی برای ویژگی هزینه های حمل و نقل انجام دهید.
# <br> درمورد نمودار jointplot و موارد کاربرد آن توضیح دهید.
# </p>
# </font>
# </div>
# </font>

# %%
#FILL HERE
plt.figure(figsize=(10, 6))
sns.jointplot(x='Distance_to_Work', y='Absence_Duration_Hours', data=df, kind='reg')
plt.xlabel('Distance to Work')
plt.ylabel('Absence Duration (Hours)')
plt.title('Relationship between Distance to Work and Absence Hours')
plt.show()

plt.figure(figsize=(10, 6))
sns.jointplot(x='Transportation_Expense', y='Absence_Duration_Hours', data=df, kind='reg')
plt.xlabel('Transportation_Expense')
plt.ylabel('Absence Duration Hours')
plt.title('Relationship between Transportation_Expense and Absence Hours')
plt.show()

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ: </font></b>  این نوع نمودار، همزمان توزیع دو متغیر را در یک نمودار نمایش می‌دهد. نمودار Joint Plot مناسب  زمانی که می‌خواهید رابطه بین دو متغیر را همزمان بررسی کنید و همچنین به توزیع دو متغیر در هر محور توجه کنید. این نمودار می‌تواند به شما کمک کند تا الگوها و روندهای موجود در داده‌ها را بهتر درک کنید و رابطه بین متغیرها را مشاهده کنید. استفاده از پارامتر kind='reg' همچنین امکان رسم یک خط رگرسیون برای بررسی رابطه خطی بین دو متغیر را فراهم می‌کند.
# </p>
# </font>
# </div>
# </font>
# <hr>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5>
# همانطور که مشاهده می‌شود، توزیع فواصل از محل اقامت تا محل کار و هزینه‌های حمل و نقل به نظر نزدیک به توزیع‌های نرمال می‌آید، در حالی که زمان غیبت به ساعت‌ها به شدت به سمت راست منحرف شده است. این موضوع باعث می‌شود مقایسه بین متغیرها دشوار باشد. یکی از راه‌حل‌های این مشکل، تبدیل داده‌ها به چیزی نزدیک به توزیع نرمال است. روشی موثر برای انجام این تبدیل، استفاده از تبدیل‌های Box-Cox یا Yeo-Johnson است که هر دو در کتابخانه scipy موجود است.
#
# 2.3. با توجه به اینکه ستون زمان غیبت شامل مقادیر صفر است از از تبدیل Yeo-Johnson استفاده کنید.
# <br>
# سپس هر دو نمودار بالا را مجددا رسم کنید و با تحلیل این این نمودارها درمورد تاثیرگذاری این دو فاکتور بر روی زمان غیبت توضیح دهید.
# </p>
# </font>
# </div>
# </font>

# %%
#FILL HERE
from scipy.stats import yeojohnson
df['Absence_Duration_Hours_transformed'], _ = yeojohnson(df['Absence_Duration_Hours'] + 1)

plt.figure(figsize=(10, 6))
sns.jointplot(x='Distance_to_Work', y='Absence_Duration_Hours_transformed', data=df, kind='reg')
plt.xlabel('Distance to Work')
plt.ylabel('Transformed Absence Duration (Hours)')
plt.title('Relationship between Distance to Work and Transformed Absence Hours')
plt.show()


plt.figure(figsize=(10, 6))
sns.jointplot(x='Transportation_Expense', y='Absence_Duration_Hours_transformed', data=df, kind='reg')
plt.xlabel('Transportation_Expense')
plt.ylabel('Transformed Absence Duration (Hours)')
plt.title('Relationship between Transportation_Expense and Transformed Absence Hours')
plt.show()

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ: </font></b>  با تبدیل داده‌های زمان غیبت با استفاده از تبدیل Yeo-Johnson، مشاهده می‌شود که توزیع زمان غیبت به سمت نرمالیته بیشتری حرکت کرده است. این تبدیل امکان مقایسه بهتری بین فواصل محل اقامت تا کار و هزینه‌های حمل و نقل با زمان غیبت را فراهم می‌کند. از این نمودارها می‌توان فهمید که چگونه فواصل بیشتر محل اقامت تا کار یا هزینه‌های حمل و نقل بیشتر می‌تواند با زمان غیبت افراد مرتبط باشد
# </p>
# </font>
# </div>
# </font>
# <hr>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <font size=5>
# <b> 4 . همبستگی </b>
# <p align="justify">
# <font size=5>
# با استفاده از heatmap همبستگی بین ویژگی ها را بررسی کنید.
# <br>
# درمورد نمودار heatmap و عملکرد آن به طور مختصر توضیح دهید.
# </p>
# </font>
# </div>
# </font>

# %%
# Select only numeric columns for correlation calculation
numeric_df = df.select_dtypes(include=['number'])

correlation_matrix = numeric_df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', cbar=True, linewidths=0.5)

plt.title('Heatmap of Correlation Matrix')
plt.show()

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ: </font></b>  لدر نمودار Heatmap، هر سلول با رنگ و مقدار خود نشان‌دهنده همبستگی بین دو ویژگی است. اگر همبستگی مثبت باشد، سلول‌ها به رنگ‌های گرمتر (مثلاً قرمز) و اگر همبستگی منفی باشد، به رنگ‌های سردتر (مثلاً آبی) خواهند بود. همچنین، عدد داخل هر سلول نشان‌دهنده مقدار همبستگی است و با استفاده از پارامتر annot=True این مقادیر نیز بر روی نمودار نمایش داده می‌شود.
#
# </p>
# </font>
# </div>
# </font>
# <hr>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <font size=5>
# <b> 5 . سن </b>
# <p align="justify">
# <font size=5>
# سن نیز ممکن است بر غیبت کارمندان تاثیر بگذارد.کارمندان سنین بالاتر ممکن است نیاز به درمان‌های پزشکی مکرر داشته باشند.
# <br>
# 1.5. با استفاده از نمودار displot درمورد توزیع سن  کارمندان و چولگی نمودار بحث کنید.
# <br>
# 2.5. جهت بررسی تاثیر سن در بیماری ها، با استفاده از violin plot توزیع سن بین دو گروه افراد براساس  ویژگی "Disease"  در قسمت 1 را نمایش دهید و تحلیل خود را از این نمودار بیان کنید.
# <br>
# 3.5. با استفاده از barplot بررسی کنید آیا افراد با سنین بالاتر ساعات بیشتری غیبت میکنند؟
# </p>
# </font>
# </div>
# </font>

# %%
age_data = df['Employee_Age']


plt.figure(figsize=(10, 6))
sns.displot(age_data, kde=True, color='blue')
plt.title('Distribution of Employee Ages')
plt.xlabel('Age')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ: </font></b>  با این نمودار میزان تاثیر سن بر روی غیبت را مشاهده می کنیم برای مثال می بینیم افراد نزدیک به 38 سال سن بیشترین تعداد غیبت رو دارند و میزان انباشتگی غیبت در این محدود 35 تا 40 بیشتراز بقیه جاها است
# </p>
# </font>
# </div>
# </font>
# <hr>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5>
# 2.5. جهت بررسی تاثیر سن در بیماری ها، با استفاده از violin plot توزیع سن بین دو گروه افراد براساس  ویژگی "Disease"  در قسمت 1 را نمایش دهید و تحلیل خود را از این نمودار بیان کنید.
# </p>
# </font>
# </div>
# </font>

# %%
#FILL HERE

plt.figure(figsize=(10, 6))
sns.violinplot(x='Disease', y='Employee_Age', data=df)
plt.title('Distribution of Age by Disease')
plt.xlabel('Disease')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ: </font></b>  این نمودار امکان مشاهده توزیع سن در هر گروه را فراهم می‌کند و به ما کمک می‌کند تا ببینیم آیا توزیع سن در هر گروه تفاوت قابل توجهی دارد یا خیر برای مثال  در false توزیع بهم ریخته تر است
# </p>
# </font>
# </div>
# </font>
# <hr>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5>
# 3.5. با استفاده از barplot در بازه های ده ساله بررسی کنید آیا افراد با سنین بالاتر ساعات بیشتری غیبت میکنند؟
# </p>
# </font>
# </div>
# </font>

# %%
age_range = df['Employee_Age'].unique()
age_range
# Out:
# array([33, 50, 38, 39, 28, 36, 34, 37, 41, 47, 29, 48, 32, 27, 43, 40, 31,
#        30, 49, 58, 46], dtype=int64)

# %%
df['Age_Group'] = pd.cut(df['Employee_Age'], bins=np.arange(20,70, 10), right=False)
plt.figure(figsize=(6,4))
#FILL HERE
mean_absence_hours = df.groupby('Age_Group')['Absence_Duration_Hours'].mean().reset_index()
plt.figure(figsize=(10, 6))
sns.barplot(x='Age_Group', y='Absence_Duration_Hours', data=mean_absence_hours, palette='coolwarm')
plt.title('Mean Absence Hours by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Mean Absence Hours')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\msi\AppData\Local\Temp\ipykernel_21812\2435849822.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_absence_hours = df.groupby('Age_Group')['Absence_Duration_Hours'].mean().reset_index()
# C:\Users\msi\AppData\Local\Temp\ipykernel_21812\2435849822.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Age_Group', y='Absence_Duration_Hours', data=mean_absence_hours, palette='coolwarm')

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ: </font></b>  این نموارد در بازه های 10 ساله میانگین ساعات غیبت را نشان می دهد که میزان ساعات غیبت در بازه بین 50 تا 60 بیشترین مقدار است
# </p>
# </font>
# </div>
# </font>
# <hr>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=5>
#
# </p>
# </font>
# </div>
# </font>

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <font size=5>
# <b> 6. بررسی سایر فاکتورها </b>
# <p align="justify">
# <font size=5>
# 1.6. با استفاده از نمودارها و روش های مناسب تاثیرگذاری این عوامل را در مرخصی کارمندان بررسی کنید.
# <br>
#
# 1.   تحصیلات:
# کارمندان با مدارک تحصیلی بالاتر که مسئولیت‌های بالاتری را بر عهده دارند، ممکن است کمتر به مشکلاتی از این دست دچار شوند.
# 2.  بررسی ساعت‌های غیبت بر اساس روز هفته و ماه سال
# 3. تعداد فرزندان
#
# </p>
# </font>
# </div>
# </font>

# %%
#FILL HERE
plt.figure(figsize=(8, 6))
sns.barplot(x='Education_Level1', y='Absence_Duration_Hours', data=df)
plt.title('Effect of Education Level on Absence Hours')
plt.xlabel('Education Level')
plt.ylabel('Mean Absence Hours')
plt.show()

plt.figure(figsize=(10, 6))
sns.barplot(x='day', y='Absence_Duration_Hours', data=df)
plt.title('Absence Hours by Day of Week')
plt.xlabel('Day of Week')
plt.ylabel('Mean Absence Hours')
plt.show()

plt.figure(figsize=(10, 6))
sns.barplot(x='month', y='Absence_Duration_Hours', data=df)
plt.title('Absence Hours by month')
plt.xlabel('month')
plt.ylabel('Mean Absence Hours')
plt.show()

plt.figure(figsize=(10, 6))
sns.barplot(x='Year', y='Absence_Duration_Hours', data=df)
plt.title('Absence Hours by year')
plt.xlabel('Year')
plt.ylabel('Mean Absence Hours')
plt.show()


plt.figure(figsize=(8, 6))
sns.scatterplot(x='Children', y='Absence_Duration_Hours', data=df)
plt.title('Effect of Number of Children on Absence Hours')
plt.xlabel('Number of Children')
plt.ylabel('Absence Hours')
plt.show()

# %% [markdown]
# <font face="B Mitra">
# <div dir=rtl>
# <p align="justify">
# <font size=4>
# <b> <font color='red'> توضیحات پاسخ: </font></b>  لطفا اینجا بنویسید
# </p>
# </font>
# </div>
# </font>
# <hr>
